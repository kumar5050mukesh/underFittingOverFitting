# %%
# Q1: Define overfitting and underfitting in machine learning. What are the consequences of each, and how
# can they be mitigated?
"""over fitting is a condition in which the accuracy  with respect to the training data is high but
 with respect to test data is low ,or we can say that  data's bias is low but variance is high .

under fitting is a situation in which the accuracy with respect to both the training and the test data is low or we 
can say that both the bias and variance is high 

**CONSEQUENCE 
suppose the test data has the noises, in this case the algorithm might pick realtionship that might not be useful or this 
condition may not apply in all future  test data, thus it will lead to the overfitting .It might work for the present 
dataset but it might not work for others test data  


in the case of the under fitting suppose there  are machine learning tool for the spam filter , it will not detect some of  
the spams 


**SOLUTIONS
we can solve overfitting by(selecting the few parameters )
(by reducing the number of the attributes in the training data )
(to gather more training data )
(to reduce the noise in the training data )

we can solve underfitting by
(Selecting a more powerful model, with more parameters)
(Feeding better features to the learning algorithm (feature engineering)
(Reducing the constraints on the model) """

# %%
# Q2: How can we reduce overfitting? Explain in brief.
"""
Overfitting occurs when a machine learning model becomes too complex and begins to fit the training data too closely,
to the point where it starts to capture noise in the data rather than the underlying patterns. 
There are several ways to reduce overfitting:

1.Increaing the amount of the training data 

2.simplify the model , the more complex the data is there is more chance of overfitting 

3.regulariztion is a technique that can result in less overfitting of the data .

4.dropout is a tecnique in which the partical node is made silent .

5we are regualary checking the model if it starts overfitting then we stop training the data """

# %%
# Q3: Explain underfitting. List scenarios where underfitting can occur in ML.
"""under fitting is the situation in which the model is quite simple it does not capture the underlying pattern in the data

there are various scenarios  where the underfitting can occur 

1.when the training data is small in this case underfitting can occur 

2.If the model is too simple to capture the underlying pattern of the data 

3. if the regularization is too large then it can result in the underfitting 

4.If the selection of the feature is poor then it can result in underfitting 


"""

# %%
# Q4: Explain the bias-variance tradeoff in machine learning. What is the relationship between bias and
# # variance, and how do they affect model performance?
"""bias the result of simlplification of the  real world scenario if the bias is too high the model
does not capture the underlying pattern and if the bias is too low the model  becomes complex and 
it can capture noise along with the underlying pattern


variance is the error that is introduced in the system due to the variation in the test data ,higher variance means 
the data may fit too closely resulting in in overfitting of the data .

so there should be a tradeoff between bias and the varaince so that the model fits well
"""

# %%
# Q5: Discuss some common methods for detecting overfitting and underfitting in machine learning models.
# How can you determine whether your model is overfitting or underfitting?

"""(1)If the training and the validation curve is plotted we find that training performance improves but the 
validation performance gets flattened we say the curves is overfitted 
 if the training and validation both the curves the perfomance does not improve we say that there is 
 underfitting 

 (2)learining curve is the curves that shows the performance with relation to amount of the training data .if the 
 if the learining cure plateaus early then we can say that the data is underfitting .
 if there is a gap between the training and the validation performance we say that this is case of overfitting 

 (3)regualariztion can add penalty to the loss function resulting in the improvement of the underfitting and the overfitting 

 (4)if the model is underfitting it may loose some of the important parameters while predicting and if the model 
 is overfitted it may capture noise in the data .
"""

# %%
# Q6: Compare and contrast bias and variance in machine learning. W"hat are some examples of high bias
# and high variance models, and how do they differ in terms of their performance?"

"""bias is the simplification of the real world problem is the bias is high , this is the case of underfitting in this case the 
model deos not capture the pattern in the data 

example of the high bias model is the linear regression and the naive bias .the linear regression model simplifies the real world
scenario and thus predicts the outcome 
naive bias similarly treats the events as independent and gives the result 



variance is the meaaure of the sensitivity of the change of the data if the variance is too large it might result in overfitting 
leading to the capture of noise in the output 

decesion tree and the neural networks are the example of high variance 

so it becomes necessary to have a proper adjustment of the bias and the variance to have required output.
"""

# %%
# Q7: What is regularization in machine learning, and how can it be used to prevent overfitting? Describe
# some common regularization techniques and how they work.
"""regulariztion is a tehnique used in the machine learning to improve underfitting and the overfitting 
there are the types 
first one is the l1 regulariztion , also called the lasso regualarization in which the penalty equal to the weight is 
added to the loss function 

second one is the l2 regualarization ,also called the ridge regualariazation in which the penalty equla to the square of 
teh weight is added it encorages the model to pick teh small weight 

dropout regulariztion is used in the neural network in which the neuron that is causing the underfititng or the overfitting is 
dropped  """
